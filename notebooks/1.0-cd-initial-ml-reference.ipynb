# %% [markdown]
# # TD5 - Implémentation d'un modèle de machine learning
# **Objectif:** Récuperer les données sur le cluster MinIO afin de les traiter par ML.
#
# ## Mode opératoire
# -> Inférer le **prix payé** en fonction de paramètres que l'on jugera utile.
#
# * Métrique: RMSE (valeur minimale: 10), d'autres métriques à justifier dans le rapport
# * Documentation: `pyment` et notation **NumpyDoc**
# * Normes: **PEP8** avec `flake8`
#
# * Bonus: Faire un Front-End avec `streamlit`!
